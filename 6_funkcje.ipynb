# %% [markdown]
# Definicja funkcji w pythonie
#
#
# def funkcja():
#   ciało funkcji

# %%
def dodawanie(x,y):
  wynik = x+y
  return wynik

# %%
dodawanie(x=10, y=5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-62f9e581ec1c> in <module>()
# ----> 1 dodawanie(x=10, y=5)
#
# TypeError: dodawanie() got an unexpected keyword argument 'x'
